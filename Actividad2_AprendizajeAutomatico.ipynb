# %% [markdown]
# <a href="https://colab.research.google.com/github/pacho9090/hyperblog/blob/master/Actividad2_AprendizajeAutomatico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ACTIVIDAD 2 - Métodos de Aprendizaje Automático**
#
# GRUPO 5
# Diaz Cuesta, Yeffer
# Valbuena Acosta, Carlos
# Pizarro Rivera, Francisco

# %%
## Importación de librerias

import pandas as pd
import seaborn as sb
import sklearn as sk

# %%
# Cargue de datos

data = pd.read_excel("Dermato_Data.xlsx")
data
# Out:
#            1_erythema        2_scaling        3_definite borders  \
# 0                   2                2                         0
# 1                   3                3                         3
# 2                   2                1                         2
# 3                   2                2                         2
# 4                   2                3                         2
# ..                ...              ...                       ...
# 361                 2                1                         1
# 362                 3                2                         1
# 363                 3                2                         2
# 364                 2                1                         3
# 365                 3                2                         2
#
#            4_itching        5_koebner phenomenon        6_polygonal papules  \
# 0                  3                           0                          0
# ...
